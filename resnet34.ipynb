# %% [markdown]
# # AI vs Human art classification
# This project is done as part of the Context Aware Security Analytics In Computer Vision 2023/2024 course
#
# Supervised by **Carmen Bisogni**
#
# By **Zakarya Boudraf**, **Mohammed Aziz Khitmi** and **Melissa Ould Braham**
#
# ## Now we fit the model on all styles at once

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ### listing the training then the testing directories

# %%
top_dir = '../input/Real_AI_SD_LD_Dataset/'

# Define the training paths
train_dir = os.path.join(top_dir, 'train')

# List all directories in the train directory
all_directories = os.listdir(train_dir)

# Initialize lists to store directories for human-drawn and AI-generated images
train_human = []
train_ai = []

# Loop through all directories
for directory in all_directories:
    # Check if the directory represents human-drawn images
    if not directory.startswith('AI_'):
        train_human.append(os.path.join(train_dir, directory))
    # Check if the directory represents AI-generated images
    else:
        train_ai.append(os.path.join(train_dir, directory))

# Print the lists of directories
print("Train directories containing human-drawn images:")
for i, directory in enumerate(train_human):
    print(f"{i}. {directory}")

print("\nTrain directories containing AI-generated images:")
for i, directory in enumerate(train_ai):
    print(f"{i}. {directory}")
# Out:
# Train directories containing human-drawn images:
# 0. ../input/Real_AI_SD_LD_Dataset/train/impressionism
# 1. ../input/Real_AI_SD_LD_Dataset/train/renaissance
# 2. ../input/Real_AI_SD_LD_Dataset/train/surrealism
# 3. ../input/Real_AI_SD_LD_Dataset/train/art_nouveau
# 4. ../input/Real_AI_SD_LD_Dataset/train/baroque
# 5. ../input/Real_AI_SD_LD_Dataset/train/expressionism
# 6. ../input/Real_AI_SD_LD_Dataset/train/romanticism
# 7. ../input/Real_AI_SD_LD_Dataset/train/ukiyo_e
# 8. ../input/Real_AI_SD_LD_Dataset/train/post_impressionism
# 9. ../input/Real_AI_SD_LD_Dataset/train/realism
#
# Train directories containing AI-generated images:
# 0. ../input/Real_AI_SD_LD_Dataset/train/AI_SD_impressionism
# 1. ../input/Real_AI_SD_LD_Dataset/train/AI_LD_post_impressionism
# 2. ../input/Real_AI_SD_LD_Dataset/train/AI_LD_art_nouveau
# 3. ../input/Real_AI_SD_LD_Dataset/train/AI_LD_surrealism
# 4. ../input/Real_AI_SD_LD_Dataset/train/AI_LD_ukiyo-e
# 5. ../input/Real_AI_SD_LD_Dataset/train/AI_LD_romanticism
# 6. ../input/Real_AI_SD_LD_Dataset/train/AI_LD_baroque
# 7. ../input/Real_AI_SD_LD_Dataset/train/AI_LD_expressionism
# 8. ../input/Real_AI_SD_LD_Dataset/train/AI_SD_post_impressionism
# 9. ../input/Real_AI_SD_LD_Dataset/train/AI_SD_ukiyo-e
# 10. ../input/Real_AI_SD_LD_Dataset/train/AI_LD_renaissance
# 11. ../input/Real_AI_SD_LD_Dataset/train/AI_SD_renaissance
# 12. ../input/Real_AI_SD_LD_Dataset/train/AI_SD_romanticism
# 13. ../input/Real_AI_SD_LD_Dataset/train/AI_SD_realism
# 14. ../input/Real_AI_SD_LD_Dataset/train/AI_SD_baroque
# 15. ../input/Real_AI_SD_LD_Dataset/train/AI_SD_expressionism
# 16. ../input/Real_AI_SD_LD_Dataset/train/AI_LD_realism
# 17. ../input/Real_AI_SD_LD_Dataset/train/AI_SD_art_nouveau
# 18. ../input/Real_AI_SD_LD_Dataset/train/AI_SD_surrealism
# 19. ../input/Real_AI_SD_LD_Dataset/train/AI_LD_impressionism

# %%
# Define the test paths
test_dir = os.path.join(top_dir, 'test')

# List all directories in the test directory
all_directories = os.listdir(test_dir)

# Initialize lists to store directories for human-drawn and AI-generated images
test_human = []
test_ai = []

# Loop through all directories
for directory in all_directories:
    # Check if the directory represents human-drawn images
    if not directory.startswith('AI_'):
        test_human.append(os.path.join(test_dir, directory))
    # Check if the directory represents AI-generated images
    else:
        test_ai.append(os.path.join(test_dir, directory))

# Print the lists of directories
print("Test directories containing human-drawn images:")
for i, directory in enumerate(test_human):
    print(f"{i}. {directory}")

print("\nTest directories containing AI-generated images:")
for i, directory in enumerate(test_ai):
    print(f"{i}. {directory}")
# Out:
# Test directories containing human-drawn images:
# 0. ../input/Real_AI_SD_LD_Dataset/test/impressionism
# 1. ../input/Real_AI_SD_LD_Dataset/test/renaissance
# 2. ../input/Real_AI_SD_LD_Dataset/test/surrealism
# 3. ../input/Real_AI_SD_LD_Dataset/test/art_nouveau
# 4. ../input/Real_AI_SD_LD_Dataset/test/baroque
# 5. ../input/Real_AI_SD_LD_Dataset/test/expressionism
# 6. ../input/Real_AI_SD_LD_Dataset/test/romanticism
# 7. ../input/Real_AI_SD_LD_Dataset/test/ukiyo_e
# 8. ../input/Real_AI_SD_LD_Dataset/test/post_impressionism
# 9. ../input/Real_AI_SD_LD_Dataset/test/realism
#
# Test directories containing AI-generated images:
# 0. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_impressionism
# 1. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_post_impressionism
# 2. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_art_nouveau
# 3. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_surrealism
# 4. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_ukiyo-e
# 5. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_romanticism
# 6. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_baroque
# 7. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_expressionism
# 8. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_post_impressionism
# 9. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_ukiyo-e
# 10. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_renaissance
# 11. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_renaissance
# 12. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_romanticism
# 13. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_realism
# 14. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_baroque
# 15. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_expressionism
# 16. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_realism
# 17. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_art_nouveau
# 18. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_surrealism
# 19. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_impressionism

# %% [markdown]
# # Ranking the styles from easiest to hardest to classify
# 1. Realism
# 1. Renaissance
# 1. Ukiyo-e
# 1. Baroque
# 1. Post-Impressionism
# 1. Impressionism
# 1. Romanticism
# 1. Expressionism
# 1. Surrealism
# 1. Art Nouveau

# %% [markdown]
# # Model for Classifying AI-Generated images on all styles
# ## First we list the training data

# %%
# Print the lists of directories
print("Test directories containing human-drawn images:")
for i, directory in enumerate(test_human):
    print(f"{i}. {directory}")

print("\nTest directories containing AI-generated images:")
for i, directory in enumerate(test_ai):
    print(f"{i}. {directory}")
# Out:
# Test directories containing human-drawn images:
# 0. ../input/Real_AI_SD_LD_Dataset/test/impressionism
# 1. ../input/Real_AI_SD_LD_Dataset/test/renaissance
# 2. ../input/Real_AI_SD_LD_Dataset/test/surrealism
# 3. ../input/Real_AI_SD_LD_Dataset/test/art_nouveau
# 4. ../input/Real_AI_SD_LD_Dataset/test/baroque
# 5. ../input/Real_AI_SD_LD_Dataset/test/expressionism
# 6. ../input/Real_AI_SD_LD_Dataset/test/romanticism
# 7. ../input/Real_AI_SD_LD_Dataset/test/ukiyo_e
# 8. ../input/Real_AI_SD_LD_Dataset/test/post_impressionism
# 9. ../input/Real_AI_SD_LD_Dataset/test/realism
#
# Test directories containing AI-generated images:
# 0. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_impressionism
# 1. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_post_impressionism
# 2. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_art_nouveau
# 3. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_surrealism
# 4. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_ukiyo-e
# 5. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_romanticism
# 6. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_baroque
# 7. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_expressionism
# 8. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_post_impressionism
# 9. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_ukiyo-e
# 10. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_renaissance
# 11. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_renaissance
# 12. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_romanticism
# 13. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_realism
# 14. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_baroque
# 15. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_expressionism
# 16. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_realism
# 17. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_art_nouveau
# 18. ../input/Real_AI_SD_LD_Dataset/test/AI_SD_surrealism
# 19. ../input/Real_AI_SD_LD_Dataset/test/AI_LD_impressionism

# %% [markdown]
# # Labeling the training data

# %%
# Initialize lists to store file paths and labels
filepaths = []
labels = []

# Initialize an empty DataFrame for train_data
train_data = pd.DataFrame(columns=['filepath', 'label'])

# Label files under train_human as "human"
for directory in train_human:
    for file in os.listdir(directory):
        filepath = os.path.join(directory, file)
        filepaths.append(filepath)
        labels.append("human")

# Label files under train_ai as "AI"
for directory in train_ai:
    for file in os.listdir(directory):
        filepath = os.path.join(directory, file)
        filepaths.append(filepath)
        labels.append("AI")

# Create a DataFrame with file paths and labels
data = pd.DataFrame({'filepath': filepaths, 'label': labels})

# Concatenate data with train_data
train_data = pd.concat([train_data, data], ignore_index=True)

# %%
train_data
# Out:
#                                                  filepath  label
# 0       ../input/Real_AI_SD_LD_Dataset/train/impressio...  human
# 1       ../input/Real_AI_SD_LD_Dataset/train/impressio...  human
# 2       ../input/Real_AI_SD_LD_Dataset/train/impressio...  human
# 3       ../input/Real_AI_SD_LD_Dataset/train/impressio...  human
# 4       ../input/Real_AI_SD_LD_Dataset/train/impressio...  human
# ...                                                   ...    ...
# 155010  ../input/Real_AI_SD_LD_Dataset/train/AI_LD_imp...     AI
# 155011  ../input/Real_AI_SD_LD_Dataset/train/AI_LD_imp...     AI
# 155012  ../input/Real_AI_SD_LD_Dataset/train/AI_LD_imp...     AI
# 155013  ../input/Real_AI_SD_LD_Dataset/train/AI_LD_imp...     AI
# 155014  ../input/Real_AI_SD_LD_Dataset/train/AI_LD_imp...     AI
#
# [155015 rows x 2 columns]

# %% [markdown]
# ### We split the training data into training and validation subsets (80/20)

# %%
from sklearn.model_selection import train_test_split

train_data, validation_data = train_test_split(train_data, test_size=0.2)

# %%
train_data
# Out:
#                                                  filepath  label
# 58226   ../input/Real_AI_SD_LD_Dataset/train/AI_LD_pos...     AI
# 35428   ../input/Real_AI_SD_LD_Dataset/train/ukiyo_e/k...  human
# 83134   ../input/Real_AI_SD_LD_Dataset/train/AI_LD_bar...     AI
# 38029   ../input/Real_AI_SD_LD_Dataset/train/ukiyo_e/o...  human
# 45482   ../input/Real_AI_SD_LD_Dataset/train/realism/e...  human
# ...                                                   ...    ...
# 112573  ../input/Real_AI_SD_LD_Dataset/train/AI_SD_ren...     AI
# 145381  ../input/Real_AI_SD_LD_Dataset/train/AI_SD_sur...     AI
# 29593   ../input/Real_AI_SD_LD_Dataset/train/expressio...  human
# 18899   ../input/Real_AI_SD_LD_Dataset/train/art_nouve...  human
# 76485   ../input/Real_AI_SD_LD_Dataset/train/AI_LD_rom...     AI
#
# [124012 rows x 2 columns]

# %%
validation_data
# Out:
#                                                  filepath  label
# 152516  ../input/Real_AI_SD_LD_Dataset/train/AI_LD_imp...     AI
# 88334   ../input/Real_AI_SD_LD_Dataset/train/AI_LD_exp...     AI
# 38629   ../input/Real_AI_SD_LD_Dataset/train/ukiyo_e/u...  human
# 20895   ../input/Real_AI_SD_LD_Dataset/train/baroque/w...  human
# 46015   ../input/Real_AI_SD_LD_Dataset/train/realism/d...  human
# ...                                                   ...    ...
# 25758   ../input/Real_AI_SD_LD_Dataset/train/expressio...  human
# 126739  ../input/Real_AI_SD_LD_Dataset/train/AI_SD_bar...     AI
# 112802  ../input/Real_AI_SD_LD_Dataset/train/AI_SD_rom...     AI
# 98347   ../input/Real_AI_SD_LD_Dataset/train/AI_SD_uki...     AI
# 32450   ../input/Real_AI_SD_LD_Dataset/train/romantici...  human
#
# [31003 rows x 2 columns]

# %%
# Count the number of files under each label
file_counts = train_data['label'].value_counts()

# Print the counts
print("Number of files under each label:")
print(file_counts)
# Out:
# Number of files under each label:
# label
# AI       83971
# human    40041
# Name: count, dtype: int64

# %%
# Initialize lists to store file paths and labels
filepaths = []
labels = []

# Initialize an empty DataFrame for test_data
test_data = pd.DataFrame(columns=['filepath', 'label'])

# Label files under test_human as "human"
for directory in test_human:
    for file in os.listdir(directory):
        filepath = os.path.join(directory, file)
        filepaths.append(filepath)
        labels.append("human")

# Label files under test_ai as "AI"
for directory in test_ai:
    for file in os.listdir(directory):
        filepath = os.path.join(directory, file)
        filepaths.append(filepath)
        labels.append("AI")

# Create a DataFrame with file paths and labels
data = pd.DataFrame({'filepath': filepaths, 'label': labels})

# Concatenate data with test_data
test_data = pd.concat([test_data, data], ignore_index=True)

# %%
test_data
# Out:
#                                                 filepath  label
# 0      ../input/Real_AI_SD_LD_Dataset/test/impression...  human
# 1      ../input/Real_AI_SD_LD_Dataset/test/impression...  human
# 2      ../input/Real_AI_SD_LD_Dataset/test/impression...  human
# 3      ../input/Real_AI_SD_LD_Dataset/test/impression...  human
# 4      ../input/Real_AI_SD_LD_Dataset/test/impression...  human
# ...                                                  ...    ...
# 29995  ../input/Real_AI_SD_LD_Dataset/test/AI_LD_impr...     AI
# 29996  ../input/Real_AI_SD_LD_Dataset/test/AI_LD_impr...     AI
# 29997  ../input/Real_AI_SD_LD_Dataset/test/AI_LD_impr...     AI
# 29998  ../input/Real_AI_SD_LD_Dataset/test/AI_LD_impr...     AI
# 29999  ../input/Real_AI_SD_LD_Dataset/test/AI_LD_impr...     AI
#
# [30000 rows x 2 columns]

# %%
# Count the number of files under each label
file_counts = test_data['label'].value_counts()

# Print the counts
print("Number of files under each label:")
print(file_counts)
# Out:
# Number of files under each label:
# label
# AI       20000
# human    10000
# Name: count, dtype: int64

# %% [markdown]
# ### Creating the Training and Validation sets

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import image_dataset_from_directory

training_generator = ImageDataGenerator(rescale=1./255,   # to normalize pixel value
                                       # rotation_range=7, # it will apply rotations to the image
                                       # horizontal_flip=True, # it will flip image horizontally
                                       # zoom_range=0.2  # it will increase and decrease zoom by 0.2x
                                       )
train_dataset = training_generator.flow_from_dataframe(
    dataframe=train_data,
    x_col='filepath',  # Column containing file paths
    y_col='label',     # Column containing labels
    target_size=(32, 32),
    batch_size=64,
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 124012 validated image filenames belonging to 2 classes.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import image_dataset_from_directory

validation_generator = ImageDataGenerator(rescale=1./255,   # to normalize pixel value
                                       # rotation_range=7, # it will apply rotations to the image
                                       # horizontal_flip=True, # it will flip image horizontally
                                       # zoom_range=0.2  # it will increase and decrease zoom by 0.2x
                                       )
validation_dataset = validation_generator.flow_from_dataframe(
    dataframe=validation_data,
    x_col='filepath',  # Column containing file paths
    y_col='label',     # Column containing labels
    target_size=(32, 32),
    batch_size=64,
    class_mode='categorical',  
    shuffle=True
)
# Out:
# Found 31003 validated image filenames belonging to 2 classes.

# %%
train_dataset.class_indices
# Out:
# {'AI': 0, 'human': 1}

# %% [markdown]
# ### Creating the Test set

# %%
test_generator = ImageDataGenerator(rescale=1./255)
test_dataset = test_generator.flow_from_dataframe(  dataframe=test_data,
                                                    x_col='filepath',  # Column containing file paths
                                                    y_col='label',     # Column containing labels
                                                    target_size = (32, 32),
                                                    batch_size = 1,    # 1 image at a time to evaluate the NN
                                                    class_mode = 'categorical',
                                                    shuffle = False)   # to associate the prediction with expected output

test_dataset.class_indices
# Out:
# Found 30000 validated image filenames belonging to 2 classes.
# {'AI': 0, 'human': 1}

# %% [markdown]
# ### Building the neural network

# %%
from keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, MaxPooling2D, GlobalAveragePooling2D, Dense
from keras.models import Model
from keras.optimizers import Adam

def residual_block(x, filters, kernel_size=3, stride=1, downsample=False):
    identity = x
    
    if downsample:
        stride = 2
        identity = Conv2D(filters, (1, 1), strides=stride, padding='same')(identity)
        identity = BatchNormalization()(identity)
    
    x = Conv2D(filters, kernel_size, strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(filters, kernel_size, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    
    x = Add()([x, identity])
    x = Activation('relu')(x)
    
    return x

def build_resnet34(input_shape=(32, 32, 3), num_classes=2):
    inputs = Input(shape=input_shape)
    
    # Initial Convolutional Layer
    x = Conv2D(64, (7, 7), strides=2, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((3, 3), strides=2, padding='same')(x)
    
    # Residual Blocks
    for filters, blocks, downsample in zip([64, 128, 256, 512], [3, 4, 6, 3], [False, True, True, True]):
        for i in range(blocks):
            x = residual_block(x, filters, downsample=(i == 0 and downsample))
    
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs, outputs)
    return model

# Define the model
model = build_resnet34(input_shape=(32, 32, 3), num_classes=2)

# Compile the model
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Model summary
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 16, 16,    │      9,472 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 16, 16,    │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 8, 8, 64)  │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 8, 8, 64)  │     36,928 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 8, 8, 64)  │     36,928 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 8, 8, 64)  │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 8, 8, 64)  │     36,928 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 8, 8, 64)  │     36,928 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 8, 8, 64)  │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 8, 8, 64)  │     36,928 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 64)  │     36,928 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 8, 8, 64)  │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 4, 4, 128) │     73,856 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 128) │        512 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 4, 4, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 4, 4, 128) │    147,584 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 4, 4, 128) │      8,320 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 128) │        512 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 128) │        512 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 4, 4, 128) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 4, 4, 128) │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 4, 4, 128) │    147,584 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 128) │        512 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 4, 4, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 4, 4, 128) │    147,584 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 128) │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 4, 4, 128) │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 4, 4, 128) │          0 │ add_4[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 4, 4, 128) │    147,584 │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 128) │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 4, 4, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 4, 4, 128) │    147,584 │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 128) │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 4, 4, 128) │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 4, 4, 128) │          0 │ add_5[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 4, 4, 128) │    147,584 │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 128) │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 4, 4, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 4, 4, 128) │    147,584 │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 128) │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 4, 4, 128) │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 4, 4, 128) │          0 │ add_6[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 2, 2, 256) │    295,168 │ activation_14[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 256) │      1,024 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 2, 2, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 2, 2, 256) │    590,080 │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 2, 2, 256) │     33,024 │ activation_14[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 256) │      1,024 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 256) │      1,024 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 2, 2, 256) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 2, 2, 256) │          0 │ add_7[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 2, 2, 256) │    590,080 │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 256) │      1,024 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 2, 2, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 2, 2, 256) │    590,080 │ activation_17[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 256) │      1,024 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 2, 2, 256) │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 2, 2, 256) │          0 │ add_8[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 2, 2, 256) │    590,080 │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 256) │      1,024 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 2, 2, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 2, 2, 256) │    590,080 │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 256) │      1,024 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 2, 2, 256) │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 2, 2, 256) │          0 │ add_9[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 2, 2, 256) │    590,080 │ activation_20[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 256) │      1,024 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 2, 2, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 2, 2, 256) │    590,080 │ activation_21[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 256) │      1,024 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 2, 2, 256) │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_20[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 2, 2, 256) │          0 │ add_10[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 2, 2, 256) │    590,080 │ activation_22[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 256) │      1,024 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 2, 2, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 2, 2, 256) │    590,080 │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 256) │      1,024 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 2, 2, 256) │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_22[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 2, 2, 256) │          0 │ add_11[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 2, 2, 256) │    590,080 │ activation_24[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 256) │      1,024 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 2, 2, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 2, 2, 256) │    590,080 │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 256) │      1,024 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 2, 2, 256) │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_24[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 2, 2, 256) │          0 │ add_12[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 1, 1, 512) │  1,180,160 │ activation_26[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 1, 512) │      2,048 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 1, 1, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 1, 1, 512) │  2,359,808 │ activation_27[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 1, 1, 512) │    131,584 │ activation_26[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 1, 512) │      2,048 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 1, 512) │      2,048 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 1, 1, 512) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 1, 1, 512) │          0 │ add_13[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 1, 1, 512) │  2,359,808 │ activation_28[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 1, 512) │      2,048 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 1, 1, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 1, 1, 512) │  2,359,808 │ activation_29[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 1, 512) │      2,048 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 1, 1, 512) │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_28[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 1, 1, 512) │          0 │ add_14[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 1, 1, 512) │  2,359,808 │ activation_30[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 1, 512) │      2,048 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 1, 1, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 1, 1, 512) │  2,359,808 │ activation_31[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 1, 512) │      2,048 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 1, 1, 512) │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_30[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 1, 1, 512) │          0 │ add_15[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ activation_32[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 2)         │      1,026 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 21,311,234 (81.30 MB)
#  Trainable params: 21,294,210 (81.23 MB)
#  Non-trainable params: 17,024 (66.50 KB)

# %% [markdown]
# ### We fit the model to the data (we implement checkpointing to save the weights of the maximum val_acc model)

# %%
os.makedirs('../working/models')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 os.makedirs('../working/models')
#
# File /opt/conda/lib/python3.10/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [Errno 17] File exists: '../working/models'

# %%
from keras.callbacks import ModelCheckpoint

checkpoint_filepath = '../working/models/checkpoint.model.keras'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# Model is saved at the end of every epoch, if it's the best seen so far.

# %%
import time

# Initial epoch count
epochs = 5

# Initialize total training time
total_training_time = 0


# Record start time
start_time = time.time()

# Fit the model for the specified number of epochs
history = model.fit(train_dataset, epochs=epochs, validation_data=validation_dataset, callbacks=[model_checkpoint_callback])

# Calculate training time for the current batch of epochs
training_time = time.time() - start_time

# Print total training time
print("Total training time so far: {:.2f} seconds".format(training_time))
# Out:
# Epoch 1/5
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1938/1938 ━━━━━━━━━━━━━━━━━━━━ 5294s 3s/step - accuracy: 0.8573 - loss: 0.3423 - val_accuracy: 0.8764 - val_loss: 0.2822
# Epoch 2/5
# 1938/1938 ━━━━━━━━━━━━━━━━━━━━ 5128s 3s/step - accuracy: 0.9053 - loss: 0.2385 - val_accuracy: 0.8894 - val_loss: 0.2746
# Epoch 3/5
# 1036/1938 ━━━━━━━━━━━━━━━━━━━━ 38:39 3s/step - accuracy: 0.9233 - loss: 0.1908

# %% [markdown]
# ### Evaluating the network

# %%
history.history.keys()

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['accuracy']);
plt.xlabel('Epoch')
plt.ylabel('Training Accuracy')
plt.title('Training Accuracy over Epochs')
plt.show()

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['val_accuracy']);
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.title('Validation Accuracy over Epochs')
plt.show()

# %%
plt.plot(history.history['loss']);
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.title('Training Loss over Epochs')
plt.show()

# %%
plt.plot(history.history['val_loss']);
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title('Validation Loss over Epochs')
plt.show()

# %% [markdown]
# ## Reviewing the results
# We notice from the graphs of our first approach that our models need more epochs to stablize.

# %%
# The model weights (that are considered the best) can be loaded as -
model.load_weights(checkpoint_filepath)

# %%
predictions = model.predict(test_dataset)
predictions

# %%
test_dataset.class_indices

# %%
predictions = np.argmax(predictions, axis = 1)
predictions

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# Calculate confusion matrix and classification report
cm = confusion_matrix(test_dataset.classes, predictions)
report = classification_report(test_dataset.classes, predictions)

# Define custom labels for the axes
labels = ['AI', 'Human']
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Plot confusion matrix using Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')

# Add labels to the axes
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')

# Print classification report
print(report)

# Show the plot
plt.show()

# %% [markdown]
# ### Suggested solutions
# Training for too long can cause overfitting, while training for too short a time leads to underfitting.
#
# We suggest implementing Early Stopping as a solution, Early stopping helps prevent this by allowing you to train for a flexible amount of time based on when the model's performance on a separate validation dataset plateaus.

# %%
from keras.models import Sequential
from keras.layers import Rescaling, Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Activation, Dropout
from keras.metrics import Precision, Recall

from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

model_2 = Sequential()
model_2.add(Conv2D(filters = 512, kernel_size = 3, input_shape = (32,32,3), activation='relu'))
model_2.add(MaxPooling2D())
model_2.add(Conv2D(filters = 128, kernel_size = 3, activation='relu'))
model_2.add(MaxPooling2D())
model_2.add(Conv2D(filters = 32, kernel_size = 3, activation='relu'))
model_2.add(MaxPooling2D())
model_2.add(Flatten())
# MLP
# adding the first hidden layer 
model_2.add(Dense(units = 32, activation = 'relu', input_dim = 64))

# adding the second hidden layer 
model_2.add(Dense(units = 16, activation = 'relu'))

# adding the output layer 
model_2.add(Dense(units = 2, activation = 'softmax')) 

model_2.compile(optimizer = 'adam', loss = 'binary_crossentropy' , metrics = ['accuracy'] )  

model_2.summary()

# %%
from keras.callbacks import ModelCheckpoint

checkpoint_filepath = '../working/models/checkpoint.model_2.keras'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# Model is saved at the end of every epoch, if it's the best seen so far.

# %%
import time

# Initial epoch count
epochs = 30

# Initialize total training time
total_training_time = 0


# Record start time
start_time = time.time()

# Fit the model for the specified number of epochs
history = model_2.fit(train_dataset, epochs=epochs, validation_data=validation_dataset, callbacks=[model_checkpoint_callback])

# Calculate training time for the current batch of epochs
training_time = time.time() - start_time

# Print total training time
print("Total training time so far: {:.2f} seconds".format(training_time))

# %%
history.history.keys()

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['accuracy']);
plt.xlabel('Epoch')
plt.ylabel('Training Accuracy')
plt.title('Training Accuracy over Epochs')
plt.show()

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['val_accuracy']);
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.title('Validation Accuracy over Epochs')
plt.show()

# %%
plt.plot(history.history['loss']);
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.title('Training Loss over Epochs')
plt.show()

# %%
plt.plot(history.history['val_loss']);
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title('Validation Loss over Epochs')
plt.show()

# %% [markdown]
# ## Reviewing the results
# We notice from the graphs of our first approach that our models need more epochs to stablize.

# %%
# The model weights (that are considered the best) can be loaded as -
model_2.load_weights("/kaggle/working/models/checkpoint.model_2.keras")

# %%
predictions = model_2.predict(test_dataset)
predictions

# %%
test_dataset.class_indices

# %%
predictions = np.argmax(predictions, axis = 1)
predictions

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# Calculate confusion matrix and classification report
cm = confusion_matrix(test_dataset.classes, predictions)
report = classification_report(test_dataset.classes, predictions)

# Define custom labels for the axes
labels = ['AI', 'Human']
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Plot confusion matrix using Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')

# Add labels to the axes
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')

# Print classification report
print(report)

# Show the plot
plt.show()
